# %%
import pandas as pd

# %%
path = r"H:\phyton\Analise Dados\parte1\Tabela 1.1.1.xls"

# %%
indicador_1 = pd.read_excel(path, engine="xlrd")

# %%
indicador_1
# Out:
#    Tabela 1.1.1 - Número médio de horas semanais dedicadas aos cuidados de pessoas e/ou afazeres domésticos das pessoas de 14 anos ou mais de idade, na semana de referência, por sexo e cor ou raça, segundo Grandes Regiões e Unidades da Federação - Brasil - 2022  \
# 0                                                 NaN
# 1                                                 NaN
# 2             Grandes Regiões e Unidades da Federação
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              Brasil
# 8                                               Norte
# 9                                            Rondônia
# 10                                               Acre
# 11                                           Amazonas
# 12                                            Roraima
# ...

# %%
mg = indicador_1.loc[indicador_1["uf_regiao"] == "Minas Gerais"].iloc[0]

print(
"1.-", mg["mulher_preta_parda"] - mg["mulher_branca"],
"horas a mais"
)



brasil = indicador_1.loc[indicador_1["uf_regiao"] == "Brasil"].iloc[0]

print(
"2.-", brasil["mulher_preta_parda"] - brasil["homem_branca"],
"horas a mais"
)



ap = indicador_1.loc[indicador_1["uf_regiao"] == "Amapá"].iloc[0]

print(
"3.-", ap["mulher_preta_parda"] - ap["mulher_branca"],
"horas a mais"
)



pr = indicador_1.loc[indicador_1["uf_regiao"] == "Paraná"].iloc[0]

print(
"4.-", pr["mulher_preta_parda"] - pr["mulher_branca"],
"horas a mais"
)



norte = indicador_1.loc[indicador_1["uf_regiao"] == "Norte"].iloc[0]
nordeste = indicador_1.loc[indicador_1["uf_regiao"] == "Nordeste"].iloc[0]
sudeste = indicador_1.loc[indicador_1["uf_regiao"] == "Sudeste"].iloc[0]
sul = indicador_1.loc[indicador_1["uf_regiao"] == "Sul"].iloc[0]
centro_oeste = indicador_1.loc[indicador_1["uf_regiao"] == "Centro-Oeste"].iloc[0]

print("5. Norte:", norte["mulher_preta_parda"] - norte["mulher_branca"])
print(" Nordeste:", nordeste["mulher_preta_parda"] - nordeste["mulher_branca"])
print(" Sudeste:", sudeste["mulher_preta_parda"] - sudeste["mulher_branca"])
print(" Sul:", sul["mulher_preta_parda"] - sul["mulher_branca"])
print(" Centro-Oeste:", centro_oeste["mulher_preta_parda"] - centro_oeste["mulher_branca"])

# %% [markdown]
# 1- 0.8891014506799948 horas a mais
#
# 2- 10.332862174932696 horas a mais
#
# 3- -0.7400921547894974 horas a mais
#
# 4- 0.4687192965505709 horas a mais
#
# 5-  Norte: 1.2384078894508548
#     Nordeste: 0.9720500250014368
#     Sudeste: 1.2574622152363126
#     Sul: 0.3257652468676966
#     Centro-Oeste: 1.1103571965958636
